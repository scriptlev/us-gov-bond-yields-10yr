# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd

# %%
# %matplotlib inline

# %%
open('monthly.csv','r').readlines()[:10]
# Out:
# ['<!DOCTYPE html>\n',
#  '<html lang="en">\n',
#  '  <head>\n',
#  '    <meta charset="utf-8">\n',
#  '    <title>\n',
#  '      bond-yields-us-10y - DataHub - Frictionless Data\n',
#  '    </title>\n',
#  '    <meta name="author" content="Datopian">\n',
#  '    <meta name="description" content="bond-yields-us-10y. Data online made easy. Share and find data, quickly and easily. Simple, solid, slick. Frictionless and fast. Built for data scientists and wranglers. Managed by Datopian and Open Knowledge International">\n',
#  '    <meta name="keywords" content="data,datasets,data publishing,data sharing,data hosting,data package,reference data,indicators">\n']

# %%
yld = pd.read_csv('/home/da/Downloads/monthly.csv',parse_dates=['Date'])

# %%
yld.dtypes
# Out:
# Date    datetime64[ns]
# Rate           float64
# dtype: object

# %%
yld.head()
# Out:
#         Date  Rate
# 0 1953-04-11  2.83
# 1 1953-05-11  3.05
# 2 1953-06-11  3.11
# 3 1953-07-11  2.93
# 4 1953-08-11  2.95

# %%
yld = yld.sort_values(by='Date')

# %%
yld.set_index('Date',inplace=True)

# %%
yld['Rate'].plot(figsize=(16, 12))

# %%
yld.truncate(before='2005-01-01')['Rate'].plot(figsize=(16, 12))
